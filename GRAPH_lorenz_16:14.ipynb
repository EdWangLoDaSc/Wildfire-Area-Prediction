# %% [markdown]
# <a href="https://colab.research.google.com/github/EdWangLoDaSc/Wildfire-Area-Prediction/blob/main/GRAPH_lorenz_16%3A14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
from keras.layers import Conv2D,ConvLSTM2D,Conv3D,Cropping2D
from keras.layers import Input, Dropout, TimeDistributed, RepeatVector,Activation
from keras.layers import MaxPooling2D, UpSampling2D, BatchNormalization,Flatten, Dense, Reshape, LSTM
from keras import losses, Sequential
from keras import layers
from keras.callbacks import EarlyStopping
from keras.models import Model
from keras.optimizers import RMSprop, Adam
import keras
from sklearn.preprocessing import MinMaxScaler


# Create an empty graph, 平均度=25， 1000 nodes
G = nx.barabasi_albert_graph(1000, 2) 

# Define the Lorenz system parameters,混沌系统，try different paramsters,general+test differentr models
sigma = 1
rho = 1.5
beta = 8/3

# Define the initial state of the nodes，+interval
initial_state = np.random.rand(1000, 3)

# Define the coupling strength
alpha = 0.1

# Plot the final state of the nodes
#plt.hist(current_state[:,0])
#plt.show()

# %%
nx.draw(G, with_labels=True)

# %% [markdown]
# For timestepm, should try
# input length = out length
# 不同的参数
# 看节点之间差别的大
# range-成train datasets
# Train GCNLstm
# Train LSTM

# %% [markdown]
# # Some Functions

# %%
# Some fixed papamesters: G(1000,2),  alpha:0.1
def G_Lorenz(sigma,rho,beta,time_steps):

    historical_state = np.zeros((time_steps,500,3))
    current_state = initial_state
    for i in range(time_steps):
        current_state = update_state(G, current_state, alpha, sigma, rho, beta)
        historical_state[i,:,:] = current_state
    
    return current_state,historical_state

def update_state(G, state, alpha, sigma, rho, beta):
    new_state = state.copy()
    for node in G.nodes():
        neighbors = G.neighbors(node)
        x, y, z = state[node]
        dx = sigma*(y - x)
        dy = x*(rho - z) - y
        dz = x*y - beta*z
        dx_neigh, dy_neigh, dz_neigh = np.mean([state[neighbor] for neighbor in neighbors], axis=0)
        new_state[node] = state[node] + alpha*np.array([dx+dx_neigh, dy+dy_neigh, dz+dz_neigh])
    return new_state

# %%
G = nx.barabasi_albert_graph(500, 2) 
initial_state = np.random.rand(500, 3)

# %% [markdown]
# # Type 1

# %% [markdown]
# ## 2,2,8/3

# %%
current_state_1, historical_state_1 = G_Lorenz(2,2,8/3,2000)

# %%
plt.plot(historical_state_1[:,490,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f96ec31c7f0>,
#  <matplotlib.lines.Line2D at 0x7f96ec31c940>,
#  <matplotlib.lines.Line2D at 0x7f96ec31ca00>]

# %%
plt.plot(historical_state_1[:,400,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f96e5c72f40>,
#  <matplotlib.lines.Line2D at 0x7f96e5c5a0d0>,
#  <matplotlib.lines.Line2D at 0x7f96e5c5a190>]

# %%
current_state_t, historical_state_t = G_Lorenz(2,2.5,8/3,10000)

# %%
plt.plot(historical_state_t2[:,490,0])

# %%
current_state_t2, historical_state_t2 = G_Lorenz(2,3,8/3,6000)

# %%
plt.plot(historical_state_1[:40000,492,1])

# %%
historical_state_1.shape
# Out:
# (40000, 500, 3)

# %%
current_state_1, historical_state_1 = G_Lorenz(2,3.5,8/3,40000)

# %% [markdown]
# ## 4，2.5，3

# %%
current_state_t3, historical_state_t3 = G_Lorenz(4,2.5,3,2000)

# %%
 plt.plot(historical_state_t3[:,490,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f96b0266bb0>,
#  <matplotlib.lines.Line2D at 0x7f96b0266d00>,
#  <matplotlib.lines.Line2D at 0x7f96b0266dc0>]

# %% [markdown]
# # 4, 4.5, 2

# %%
current_state_3, historical_state_3 = G_Lorenz(4,4.5,8/3,10000)

# %%
plt.plot(historical_state_3[:,400,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f599a439220>,
#  <matplotlib.lines.Line2D at 0x7f599a439370>,
#  <matplotlib.lines.Line2D at 0x7f599a439430>]

# %%
plt.plot(historical_state_3[:,431,0])

# %% [markdown]
# ## 3, 3,8/3

# %%
current_state_4, historical_state_4 = G_Lorenz(4,5,8/3,50)
# Out:
# <ipython-input-60-f6fe18435df4>:18: RuntimeWarning: overflow encountered in double_scalars
#   dy = x*(rho - z) - y
# <ipython-input-60-f6fe18435df4>:19: RuntimeWarning: overflow encountered in double_scalars
#   dz = x*y - beta*z

# %%
plt.plot(historical_state_4[:,50,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f599a2585e0>,
#  <matplotlib.lines.Line2D at 0x7f599a258730>,
#  <matplotlib.lines.Line2D at 0x7f599a2587f0>]

# %%
plt.plot(historical_state_4[:,999,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f2137daa0d0>,
#  <matplotlib.lines.Line2D at 0x7f2137daa6d0>,
#  <matplotlib.lines.Line2D at 0x7f2137daad30>]

# %% [markdown]
# # 1, 1.5,8/3

# %%
current_state_5, historical_state_5 = G_Lorenz(0.5,1.5,8/3,70)
# Out:
# <ipython-input-60-f6fe18435df4>:18: RuntimeWarning: overflow encountered in double_scalars
#   dy = x*(rho - z) - y
# <ipython-input-60-f6fe18435df4>:19: RuntimeWarning: overflow encountered in double_scalars
#   dz = x*y - beta*z
# <ipython-input-60-f6fe18435df4>:21: RuntimeWarning: invalid value encountered in double_scalars
#   new_state[node] = state[node] + alpha*np.array([dx+dx_neigh, dy+dy_neigh, dz+dz_neigh])
# <ipython-input-60-f6fe18435df4>:18: RuntimeWarning: invalid value encountered in double_scalars
#   dy = x*(rho - z) - y
# <ipython-input-60-f6fe18435df4>:21: RuntimeWarning: invalid value encountered in add
#   new_state[node] = state[node] + alpha*np.array([dx+dx_neigh, dy+dy_neigh, dz+dz_neigh])
# <ipython-input-60-f6fe18435df4>:19: RuntimeWarning: invalid value encountered in double_scalars
#   dz = x*y - beta*z

# %%
plt.plot(historical_state_5[:20,100,:])

# %%
plt.plot(historical_state_5[:,2,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f2137a90850>,
#  <matplotlib.lines.Line2D at 0x7f2137a909a0>,
#  <matplotlib.lines.Line2D at 0x7f2137a90a60>]

# %% [markdown]
# # 1, 1,8/3

# %%
current_state_6, historical_state_6 = G_Lorenz(1,1,8/3,140)

# %%
plt.plot(historical_state_6[:,999,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f21384fd910>,
#  <matplotlib.lines.Line2D at 0x7f21384fda60>,
#  <matplotlib.lines.Line2D at 0x7f21384fdb20>]

# %%
plt.plot(historical_state_6[:,990,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f2137b4cdf0>,
#  <matplotlib.lines.Line2D at 0x7f2137b4cf40>,
#  <matplotlib.lines.Line2D at 0x7f2137b4cfa0>]

# %%
historical_state_6.shape
# Out:
# (140, 1000, 3)

# %%
叠加起来，140*3000 5-5
# Out:
#   File "<ipython-input-23-94b58eecebf6>", line 1
#     叠加起来，140*3000 5-5
#            ^
# SyntaxError: invalid character in identifier

# %%
#train_dataset = np.vstack((historical_state_1,historical_state_2,historical_state_3,historical_state_4,historical_state_5,historical_state_6))
train_dataset = historical_state_1

# %%
train_dataset.shape
# Out:
# (2000, 1000, 3)

# %%
#datasets = train_dataset.reshape(2680,3000)

datasets = train_dataset.reshape(2000,3000)
train = datasets[:1700,:]
valid = datasets[1700:,:]

# %%
train.shape
# Out:
# (1700, 3000)

# %% [markdown]
# # LSTM_1

# %%
#train_dataset = np.vstack((historical_state_1,historical_state_t2,historical_state_t3))
train_dataset = historical_state_1
train_len = len(train_dataset)
datasets = train_dataset.reshape(train_len,1500)
train = datasets[:1500,:]
valid = datasets[1500:,:]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))

train_sca = scaler.fit_transform(train).astype('float32')
test_sca = scaler.transform(valid).astype('float32')
slices_train = np.split(train_sca, len(train)/4)
train_dataset = np.stack(slices_train, axis=0)
slices_test = np.split(test_sca, len(valid)/4)
val_dataset = np.stack(slices_test, axis=0)

# %%
train_dataset.shape
# Out:
# (375, 4, 1500)

# %%
def create_shifted_frames(data):
    x = data[0 : data.shape[0] - 1, :, :]
    y = data[1 : data.shape[0], :, :]
    return x, y
x_train, y_train = create_shifted_frames(train_dataset)
x_val, y_val = create_shifted_frames(val_dataset)
x_train.shape
# Out:
# (374, 4, 1500)

# %%
model = Sequential()

model.add(LSTM(64,input_shape=(4,1500)))
model.add(Dropout(0.25))

model.add(RepeatVector(4))

#multi-step
model.add(LSTM(64, activation='relu', return_sequences=True))

#model.add(Dropout(0.25))
#model.add(BatchNormalization())



#model.add(Dense(128))


model.add(TimeDistributed(Dense(1500)))

model.add(Activation('relu'))

##################################################################
#training

model.compile(loss='mse', optimizer='rmsprop', metrics=['mae'])
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_51 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_50 (LSTM)              (None, 64)                400640
#
#  dropout_26 (Dropout)        (None, 64)                0
#
#  repeat_vector_25 (RepeatVec  (None, 4, 64)            0
#  tor)
#
#  lstm_51 (LSTM)              (None, 4, 64)             33024
#
#  time_distributed_25 (TimeDi  (None, 4, 1500)          97500
#  stributed)
#
#  activation_25 (Activation)  (None, 4, 1500)           0
#
# =================================================================
# Total params: 531,164
# Trainable params: 531,164
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5)
history = model.fit(x_train, y_train,validation_data=(x_val, y_val), epochs=100,callbacks=[early_stopping, reduce_lr],batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 374/374 [==============================] - 6s 11ms/step - loss: 0.0656 - mae: 0.1694 - val_loss: 0.0363 - val_mae: 0.1031 - lr: 0.0010
# Epoch 2/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0431 - mae: 0.1278 - val_loss: 0.0403 - val_mae: 0.1553 - lr: 0.0010
# Epoch 3/100
# 374/374 [==============================] - 4s 10ms/step - loss: 0.0323 - mae: 0.1090 - val_loss: 0.0261 - val_mae: 0.1162 - lr: 0.0010
# Epoch 4/100
# 374/374 [==============================] - 4s 10ms/step - loss: 0.
100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0032 - mae: 0.0360 - val_loss: 0.0015 - val_mae: 0.0298 - lr: 0.0010
# Epoch 33/100
# 374/374 [==============================] - 4s 10ms/step - loss: 0.0031 - mae: 0.0366 - val_loss: 8.0523e-04 - val_mae: 0.0135 - lr: 0.0010
# Epoch 34/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0016 - mae: 0.0220 - val_loss: 5.7260e-04 - val_mae: 0.0034 - lr: 1.0000e-04
# Epoch 35/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0014 - mae: 0.0189 - val_loss: 5.6696e-04 - val_mae: 0.0026 - lr: 1.0000e-04
# Epoch 36/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0015 - mae: 0.0183 - val_loss: 5.8277e-04 - val_mae: 0.0049 - lr: 1.0000e-04
# Epoch 37/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0015 - mae: 0.0181 - val_loss: 6.4919e-04 - val_mae: 0.0099 - lr: 1.0000e-04
# Epoch 38/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0016 - mae: 0.0185 - val_loss: 5.6716e-04 - val_mae: 0.0025 - lr: 1.0000e-04
# Epoch 39/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0014 - mae: 0.0179 - val_loss: 5.6871e-04 - val_mae: 0.0030 - lr: 1.0000e-04
# Epoch 40/100
# 374/374 [==============================] - 4s 10ms/step - loss: 0.0015 - mae: 0.0170 - val_loss: 5.6515e-04 - val_mae: 0.0021 - lr: 1.0000e-05
# Epoch 41/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0015 - mae: 0.0174 - val_loss: 5.6492e-04 - val_mae: 0.0020 - lr: 1.0000e-05
# Epoch 42/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0015 - mae: 0.0173 - val_loss: 5.6972e-04 - val_mae: 0.0033 - lr: 1.0000e-05
# Epoch 43/100
# 374/374 [==============================] - 4s 10ms/step - loss: 0.0013 - mae: 0.0160 - val_loss: 5.6689e-04 - val_mae: 0.0025 - lr: 1.0000e-05
# Epoch 44/100
# 374/374 [==============================] - 4s 10ms/step - loss: 0.0014 - mae: 0.0171 - val_loss: 5.6846e-04 - val_mae: 0.0030 - lr: 1.0000e-05
# Epoch 45/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0014 - mae: 0.0164 - val_loss: 5.6618e-04 - val_mae: 0.0023 - lr: 1.0000e-06
# Epoch 46/100
# 374/374 [==============================] - 4s 10ms/step - loss: 0.0014 - mae: 0.0169 - val_loss: 5.6589e-04 - val_mae: 0.0023 - lr: 1.0000e-06
# Epoch 47/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0013 - mae: 0.0156 - val_loss: 5.6748e-04 - val_mae: 0.0027 - lr: 1.0000e-06
# Epoch 48/100
# 374/374 [==============================] - 4s 10ms/step - loss: 0.0014 - mae: 0.0163 - val_loss: 5.6683e-04 - val_mae: 0.0026 - lr: 1.0000e-06
# Epoch 49/100
# 374/374 [==============================] - 4s 10ms/step - loss: 0.0015 - mae: 0.0171 - val_loss: 5.6526e-04 - val_mae: 0.0021 - lr: 1.0000e-06
# Epoch 50/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0014 - mae: 0.0163 - val_loss: 5.6529e-04 - val_mae: 0.0021 - lr: 1.0000e-07
# Epoch 51/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0014 - mae: 0.0166 - val_loss: 5.6534e-04 - val_mae: 0.0022 - lr: 1.0000e-07

# %%
trainPredict = model.predict(x_train)
trainPredict.shape
# Out:
# 12/12 [==============================] - 0s 3ms/step
# (374, 4, 1500)

# %%
trainPredict = model.predict(x_train).reshape((1496,1500))
testPredict = model.predict(x_val).reshape((496,1500))
y_train = y_train.reshape((1496,1500)) 
y_val = y_val.reshape((496,1500))
# Out:
# 12/12 [==============================] - 0s 4ms/step
# 4/4 [==============================] - 0s 5ms/step

# %%
trainPredict = scaler.inverse_transform(trainPredict).reshape(1496,500,3)
trainY = scaler.inverse_transform(y_train).reshape(1496,500,3)
testPredict = scaler.inverse_transform(testPredict).reshape(496,500,3)
testY = scaler.inverse_transform(y_val).reshape(496,500,3)

x_train = scaler.inverse_transform(x_train.reshape(1496,1500))

# %%
plt.plot(trainY[:200,200,0])
plt.plot(trainPredict[:200,200,0])

# %%
plt.plot(trainPredict[:,100,:])
# Out:
# [<matplotlib.lines.Line2D at 0x7f96b03cf310>,
#  <matplotlib.lines.Line2D at 0x7f96b03cff70>,
#  <matplotlib.lines.Line2D at 0x7f96b03cf220>]

# %% [markdown]
# # LSTM_2

# %%
#train_dataset = np.vstack((historical_state_1,historical_state_t2,historical_state_t3))
train_dataset = historical_state_t3
train_len = len(train_dataset)
datasets = train_dataset.reshape(train_len,1500)
train = datasets[:1500,:]
valid = datasets[1500:,:]

scaler = MinMaxScaler(feature_range=(0, 1))

train_sca = scaler.fit_transform(train).astype('float32')
test_sca = scaler.transform(valid).astype('float32')
slices_train = np.split(train_sca, len(train)/4)
train_dataset = np.stack(slices_train, axis=0)
slices_test = np.split(test_sca, len(valid)/4)
val_dataset = np.stack(slices_test, axis=0)

def create_shifted_frames(data):
    x = data[0 : data.shape[0] - 1, :, :]
    y = data[1 : data.shape[0], :, :]
    return x, y
x_train, y_train = create_shifted_frames(train_dataset)
x_val, y_val = create_shifted_frames(val_dataset)
x_train.shape
# Out:
# (374, 4, 1500)

# %%
model = Sequential()

model.add(LSTM(100,input_shape=(4,1500)))
#model.add(Dropout(0.25))

model.add(RepeatVector(4))

#multi-step
model.add(LSTM(64, activation='relu', return_sequences=True))

#model.add(Dropout(0.25))
#model.add(BatchNormalization())



#model.add(Dense(32))


model.add(TimeDistributed(Dense(1500)))

model.add(Activation('relu'))

##################################################################
#training

model.compile(loss='mse', optimizer='rmsprop', metrics=['mae'])
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_78 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_77 (LSTM)              (None, 100)               640400
#
#  repeat_vector_39 (RepeatVec  (None, 4, 100)           0
#  tor)
#
#  lstm_78 (LSTM)              (None, 4, 64)             42240
#
#  time_distributed_39 (TimeDi  (None, 4, 1500)          97500
#  stributed)
#
#  activation_39 (Activation)  (None, 4, 1500)           0
#
# =================================================================
# Total params: 780,140
# Trainable params: 780,140
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=10)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5)
history = model.fit(x_train, y_train,validation_data=(x_val, y_val), epochs=100,callbacks=[early_stopping, reduce_lr],batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 374/374 [==============================] - 6s 11ms/step - loss: 0.0671 - mae: 0.1779 - val_loss: 0.0265 - val_mae: 0.0993 - lr: 0.0010
# Epoch 2/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0244 - mae: 0.0964 - val_loss: 0.0237 - val_mae: 0.1039 - lr: 0.0010
# Epoch 3/100
# 374/374 [==============================] - 4s 10ms/step - loss: 0.0171 - mae: 0.0806 - val_loss: 0.0163 - val_mae: 0.0822 - lr: 0.0010
# Epoch 4/100
# 374/374 [==============================] - 4s 10ms/step - loss: 0.0130 - mae: 0.0716 - val_loss: 0.0134 - val_mae: 0.0737 - lr: 0.0010
# Epoch 5/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0108 - mae: 0.0660 - val_loss: 0.0140 - val_mae: 0.0825 - lr: 0.0010
# Epoch 6/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0097 - mae: 0.0627 - val_loss: 0.0109 - val_mae: 0.0679 - lr: 0.0010
# Epoch 7/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0087 - mae: 0.0589 - val_loss: 0.0118 - val_mae: 0.0750 - lr: 0.0010
# Epoch 8/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.0075 - mae: 0.0556 - val_loss: 0.0081 - val_mae: 0.0597 - lr: 0.0010
# Epoch 9/100
# 374/374 [==============================] - 3s 9ms/step - loss: 0.
# Epoch 77/100
# 374/374 [==============================] - 3s 9ms/step - loss: 8.7586e-04 - mae: 0.0136 - val_loss: 0.0024 - val_mae: 0.0298 - lr: 1.0000e-08
# Epoch 78/100
# 374/374 [==============================] - 4s 10ms/step - loss: 8.7586e-04 - mae: 0.0136 - val_loss: 0.0024 - val_mae: 0.0298 - lr: 1.0000e-08
# Epoch 79/100
# 374/374 [==============================] - 3s 9ms/step - loss: 8.7586e-04 - mae: 0.0136 - val_loss: 0.0024 - val_mae: 0.0298 - lr: 1.0000e-08

# %%
trainPredict = model.predict(x_train)
trainPredict = model.predict(x_train).reshape((1496,1500))
testPredict = model.predict(x_val).reshape((496,1500))
y_train = y_train.reshape((1496,1500)) 
y_val = y_val.reshape((496,1500)) 

trainPredict = scaler.inverse_transform(trainPredict).reshape(1496,500,3)
trainY = scaler.inverse_transform(y_train).reshape(1496,500,3)
testPredict = scaler.inverse_transform(testPredict).reshape(496,500,3)
testY = scaler.inverse_transform(y_val).reshape(496,500,3)

x_train = scaler.inverse_transform(x_train.reshape(1496,1500))
# Out:
# 12/12 [==============================] - 0s 3ms/step
# 12/12 [==============================] - 0s 3ms/step
# 4/4 [==============================] - 0s 4ms/step

# %%
plt.plot(testY[:,200,0])
plt.plot(testPredict[:,200,0])

# %% [markdown]
# # LSTM_3

# %%
#train_dataset = np.vstack((historical_state_1,historical_state_t2,historical_state_t3))
train_dataset = historical_state_3
train_len = len(train_dataset)
datasets = train_dataset.reshape(train_len,1500)
train = datasets[:8000,:]
valid = datasets[8000:,:]

scaler = MinMaxScaler(feature_range=(0, 1))

train_sca = scaler.fit_transform(train).astype('float32')
test_sca = scaler.transform(valid).astype('float32')
slices_train = np.split(train_sca, len(train)/4)
train_dataset = np.stack(slices_train, axis=0)
slices_test = np.split(test_sca, len(valid)/4)
val_dataset = np.stack(slices_test, axis=0)

def create_shifted_frames(data):
    x = data[0 : data.shape[0] - 1, :, :]
    y = data[1 : data.shape[0], :, :]
    return x, y
x_train, y_train = create_shifted_frames(train_dataset)
x_val, y_val = create_shifted_frames(val_dataset)
x_train.shape
# Out:
# (1999, 4, 1500)

# %%
model = Sequential()

model.add(LSTM(256,input_shape=(4,1500)))
#model.add(Dropout(0.25))
model.add(BatchNormalization())

model.add(RepeatVector(4))

#multi-step
#model.add(LSTM(32, activation='relu', return_sequences=True))

#model.add(Dropout(0.25))
#model.add(BatchNormalization())
model.add(LSTM(200, activation='relu', return_sequences=True))

model.add(TimeDistributed(Dense(1500)))

model.add(Activation('relu'))

##################################################################
#training

model.compile(loss='mse', optimizer='rmsprop', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential_42"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_84 (LSTM)              (None, 256)               1799168
#
#  batch_normalization_36 (Bat  (None, 256)              1024
#  chNormalization)
#
#  repeat_vector_42 (RepeatVec  (None, 4, 256)           0
#  tor)
#
#  lstm_85 (LSTM)              (None, 4, 200)            365600
#
#  time_distributed_34 (TimeDi  (None, 4, 1500)          301500
#  stributed)
#
#  activation_34 (Activation)  (None, 4, 1500)           0
#
# =================================================================
# Total params: 2,467,292
# Trainable params: 2,466,780
# Non-trainable params: 512
# _________________________________________________________________

# %%
early_stopping = keras.callbacks.EarlyStopping(monitor="val_mae", patience=10)
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor="val_mae", patience=5)
history = model.fit(x_train, y_train,validation_data=(x_val, y_val), epochs=100,callbacks=[early_stopping, reduce_lr],batch_size=8, verbose=1)
# Out:
# Epoch 1/100
# 250/250 [==============================] - 11s 32ms/step - loss: 0.0191 - mae: 0.0885 - val_loss: 0.0252 - val_mae: 0.1275 - lr: 0.0010
# Epoch 2/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0047 - mae: 0.0437 - val_loss: 0.0129 - val_mae: 0.0895 - lr: 0.0010
# Epoch 3/100
# 250/250 [==============================] - 8s 31ms/step - loss: 0.0038 - mae: 0.0389 - val_loss: 0.0588 - val_mae: 0.1960 - lr: 0.0010
# Epoch 4/100
# 250/250 [==============================] - 7s 30ms/step - loss: 0.0033 - mae: 0.0363 - val_loss: 0.0827 - val_mae: 0.2460 - lr: 0.0010
# Epoch 5/100
# 250/250 [==============================] - 8s 31ms/step - loss: 0.0031 - mae: 0.0347 - val_loss: 0.1954 - val_mae: 0.3263 - lr: 0.0010
# Epoch 6/100
# 250/250 [==============================] - 8s 31ms/step - loss: 0.0028 - mae: 0.0328 - val_loss: 0.0097 - val_mae: 0.0752 - lr: 0.0010
# Epoch 7/100
# 250/250 [==============================] - 8s 31ms/step - loss: 0.0026 - mae: 0.0319 - val_loss: 0.0344 - val_mae: 0.1447 - lr: 0.0010
# Epoch 8/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0025 - mae: 0.0310 - val_loss: 0.0537 - val_mae: 0.1729 - lr: 0.0010
# Epoch 9/100
# 250/250 [==============================] - 8s 30ms/step - loss: 0.0024 - mae: 0.0303 - val_loss: 0.0450 - val_mae: 0.1598 - lr: 0.0010
# Epoch 10/100
# 250/250 [==============================] - 8s 31ms/step - loss: 0.0023 - mae: 0.0295 - val_loss: 0.1074 - val_mae: 0.2292 - lr: 0.0010
# Epoch 11/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0023 - mae: 0.0292 - val_loss: 0.0449 - val_mae: 0.1576 - lr: 0.0010
# Epoch 12/100
# 250/250 [==============================] - 8s 30ms/step - loss: 0.0018 - mae: 0.0253 - val_loss: 0.0024 - val_mae: 0.0333 - lr: 1.0000e-04
# Epoch 13/100
# 250/250 [==============================] - 8s 31ms/step - loss: 0.0017 - mae: 0.0245 - val_loss: 0.0018 - val_mae: 0.0261 - lr: 1.0000e-04
# Epoch 14/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0016 - mae: 0.0240 - val_loss: 0.0021 - val_mae: 0.0289 - lr: 1.0000e-04
# Epoch 15/100
# 250/250 [==============================] - 8s 30ms/step - loss: 0.0016 - mae: 0.0239 - val_loss: 0.0017 - val_mae: 0.0254 - lr: 1.0000e-04
# Epoch 16/100
# 250/250 [==============================] - 8s 31ms/step - loss: 0.0016 - mae: 0.0238 - val_loss: 0.0019 - val_mae: 0.0272 - lr: 1.0000e-04
# Epoch 17/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0016 - mae: 0.0236 - val_loss: 0.0021 - val_mae: 0.0291 - lr: 1.0000e-04
# Epoch 18/100
# 250/250 [==============================] - 7s 30ms/step - loss: 0.0016 - mae: 0.0234 - val_loss: 0.0019 - val_mae: 0.0273 - lr: 1.0000e-04
# Epoch 19/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0015 - mae: 0.0234 - val_loss: 0.0017 - val_mae: 0.0257 - lr: 1.0000e-04
# Epoch 20/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0015 - mae: 0.0232 - val_loss: 0.0017 - val_mae: 0.0259 - lr: 1.0000e-04
# Epoch 21/100
# 250/250 [==============================] - 7s 30ms/step - loss: 0.0015 - mae: 0.0230 - val_loss: 0.0014 - val_mae: 0.0225 - lr: 1.0000e-05
# Epoch 22/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0015 - mae: 0.0227 - val_loss: 0.0014 - val_mae: 0.0225 - lr: 1.0000e-05
# Epoch 23/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0015 - mae: 0.0228 - val_loss: 0.0014 - val_mae: 0.0223 - lr: 1.0000e-05
# Epoch 24/100
# 250/250 [==============================] - 7s 29ms/step - loss: 0.0015 - mae: 0.0227 - val_loss: 0.0014 - val_mae: 0.0223 - lr: 1.0000e-05
# Epoch 25/100
# 250/250 [==============================] - 8s 31ms/step - loss: 0.0015 - mae: 0.0227 - val_loss: 0.0014 - val_mae: 0.0223 - lr: 1.0000e-05
# Epoch 26/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0015 - mae: 0.0229 - val_loss: 0.0014 - val_mae: 0.0224 - lr: 1.0000e-05
# Epoch 27/100
# 250/250 [==============================] - 7s 30ms/step - loss: 0.0015 - mae: 0.0228 - val_loss: 0.0014 - val_mae: 0.0222 - lr: 1.0000e-05
# Epoch 28/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0015 - mae: 0.0227 - val_loss: 0.0014 - val_mae: 0.0223 - lr: 1.0000e-05
# Epoch 29/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0015 - mae: 0.0227 - val_loss: 0.0014 - val_mae: 0.0222 - lr: 1.0000e-06
# Epoch 30/100
# 250/250 [==============================] - 7s 30ms/step - loss: 0.0014 - mae: 0.0226 - val_loss: 0.0014 - val_mae: 0.0221 - lr: 1.0000e-06
# Epoch 31/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0014 - mae: 0.0226 - val_loss: 0.0014 - val_mae: 0.0222 - lr: 1.0000e-06
# Epoch 32/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0015 - mae: 0.0226 - val_loss: 0.0014 - val_mae: 0.0222 - lr: 1.0000e-06
# Epoch 33/100
# 250/250 [==============================] - 7s 30ms/step - loss: 0.0015 - mae: 0.0227 - val_loss: 0.0014 - val_mae: 0.0221 - lr: 1.0000e-06
# Epoch 34/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0015 - mae: 0.0228 - val_loss: 0.0014 - val_mae: 0.0222 - lr: 1.0000e-06
# Epoch 35/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0014 - mae: 0.0225 - val_loss: 0.0014 - val_mae: 0.0222 - lr: 1.0000e-07
# Epoch 36/100
# 250/250 [==============================] - 7s 30ms/step - loss: 0.0015 - mae: 0.0227 - val_loss: 0.0014 - val_mae: 0.0222 - lr: 1.0000e-07
# Epoch 37/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0015 - mae: 0.0227 - val_loss: 0.0014 - val_mae: 0.0222 - lr: 1.0000e-07
# Epoch 38/100
# 250/250 [==============================] - 8s 32ms/step - loss: 0.0015 - mae: 0.0226 - val_loss: 0.0014 - val_mae: 0.0221 - lr: 1.0000e-07
# Epoch 39/100
# 250/250 [==============================] - 7s 30ms/step - loss: 0.0015 - mae: 0.0228 - val_loss: 0.0014 - val_mae: 0.0221 - lr: 1.0000e-07
# Epoch 40/100
# 250/250 [==============================] - 8s 33ms/step - loss: 0.0014 - mae: 0.0225 - val_loss: 0.0014 - val_mae: 0.0221 - lr: 1.0000e-08

# %%
trainPredict = model.predict(x_train)
trainPredict = model.predict(x_train).reshape((7996,1500))
testPredict = model.predict(x_val).reshape((1996,1500))
y_train = y_train.reshape((7996,1500)) 
y_val = y_val.reshape((1996,1500)) 

trainPredict = scaler.inverse_transform(trainPredict).reshape(7996,500,3)
trainY = scaler.inverse_transform(y_train).reshape(7996,500,3)
testPredict = scaler.inverse_transform(testPredict).reshape(1996,500,3)
testY = scaler.inverse_transform(y_val).reshape(1996,500,3)

x_train = scaler.inverse_transform(x_train.reshape(7996,1500))
# Out:
# 63/63 [==============================] - 2s 20ms/step
# 63/63 [==============================] - 1s 15ms/step
# 16/16 [==============================] - 0s 16ms/step

# %%
plt.plot(testY[:400,201,0])
plt.plot(testPredict[:400,201,0])
